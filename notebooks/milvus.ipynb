# %%
import sys
from pathlib import Path

# Get the project root (one level up from notebooks/)
project_root = Path.cwd().parent

# Add to sys.path if not already there
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Project root added to sys.path:", project_root)
# Out:
# Project root added to sys.path: /home/sunils-pg/madhan-iiitdwd/vscode/legal-assist-rag

# %%
! pip install pymilvus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymilvus
#   Downloading pymilvus-2.6.3-py3-none-any.whl.metadata (6.6 kB)
# Collecting setuptools>69 (from pymilvus)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 (from pymilvus)
#   Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting orjson>=3.10.15 (from pymilvus)
#   Downloading orjson-3.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting protobuf>=5.27.2 (from pymilvus)
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from pymilvus)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pandas>=1.2.4 (from pymilvus)
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /home/sunils-pg/.local/lib/python3.10/site-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus) (4.15.0)
# Requirement already satisfied: numpy>=1.22.4 in /home/sunils-pg/.local/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sunils-pg/.local/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2.4->pymilvus) (2022.1)
# Collecting tzdata>=2022.7 (from pandas>=1.2.4->pymilvus)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Downloading pymilvus-2.6.3-py3-none-any.whl (273 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 38.8 MB/s  0:00:00
# Downloading orjson-3.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.5 MB/s  0:00:00
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.5 MB/s  0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, setuptools, python-dotenv, protobuf, orjson, grpcio, pandas, pymilvus
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [pymilvus]7/8 [pymilvus]s]
# Successfully installed grpcio-1.76.0 orjson-3.11.4 pandas-2.3.3 protobuf-6.33.0 pymilvus-2.6.3 python-dotenv-1.2.1 setuptools-80.9.0 tzdata-2025.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
from src.vector_store.milvus_store import connect_milvus

# Connect to Milvus
client = connect_milvus()

# List all existing collections
collections = client.list_collections()

print("📚 Available Collections in Milvus:")
for c in collections:
    print(" -", c)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from src.vector_store.milvus_store import connect_milvus
#       3 # Connect to Milvus
#       4 client = connect_milvus()
#
# File ~/madhan-iiitdwd/vscode/legal-assist-rag/src/vector_store/milvus_store.py:11
#       1 """
#       2 Milvus Vector Store Module
#       3 --------------------------
#    (...)
#       8 4. Query interface for retrieval.
#       9 """
# ---> 11 from pymilvus import MilvusClient, DataType
#      12 from typing import List, Dict, Any
#      13 from src.config.settings import settings
#
# ModuleNotFoundError: No module named 'pymilvus'

# %%
import sys
from pathlib import Path

# Add project root to sys.path
project_root = Path(__file__).resolve().parents[2]  # Go up two levels: src/vector_store -> project root
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.vector_store.milvus_store import connect_milvus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pathlib import Path
#       4 # Add project root to sys.path
# ----> 5 project_root = Path(__file__).resolve().parents[2]  # Go up two levels: src/vector_store -> project root
#       6 if str(project_root) not in sys.path:
#       7     sys.path.append(str(project_root))
#
# NameError: name '__file__' is not defined
